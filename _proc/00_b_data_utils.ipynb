# %% [raw]
# ---
# description: Data download and utils
# output-file: b_data_utils.html
# title: Data utils
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(move_and_rename)
# Out:
# ---
#
# ### move_and_rename
#
# >      move_and_rename (class_dir:str)
#
# Move files from class_dir to tmp, renames them there based on count, and moves back to 2_processed class_dir: A class dir of supporting classes (Marble, Coal, ...), which contains image files.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | class_dir | str | _description_ |

# %%
#|output: asis
#| echo: false
show_doc(move_files)
# Out:
# ---
#
# ### move_files
#
# >      move_files (src_dir:str, dest_dir:str='data/2_processed/tmp')
#
# Move files to tmp directory in 2_processed.
#
# src_dir: directory of rock subclass with files [Basalt, Marble, Coal, ...]
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | src_dir | str |  | _description_ |
# | dest_dir | str | data/2_processed/tmp | _description_, by default "data/2_processed/tmp" |

# %%
#|output: asis
#| echo: false
show_doc(rename_files)
# Out:
# ---
#
# ### rename_files
#
# >      rename_files (source_dir:str='data/2_processed/tmp')
#
# Rename files in classes and moves to 2_processed.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | source_dir | str | data/2_processed/tmp | _description_, by default "data/2_processed/tmp" |

# %%
#|output: asis
#| echo: false
show_doc(get_tfds_from_dir)
# Out:
# ---
#
# ### get_tfds_from_dir
#
# >      get_tfds_from_dir (cfg)
#
# Convert directory of images to tfds dataset.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | cfg | cfg (omegaconf.DictConfig): | Hydra Configuration |
# | **Returns** | **_type_** | **_description_** |

# %%
#|output: asis
#| echo: false
show_doc(prepare)
# Out:
# ---
#
# ### prepare
#
# >      prepare (ds, cfg, shuffle=False, augment=False)
#
# Prepare dataset using augment, preprocess, cache, shuffle and prefetch.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | ds | _type_ |  | _description_ |
# | cfg | cfg (omegaconf.DictConfig): |  | Hydra Configuration |
# | shuffle | bool | False | _description_, by default False |
# | augment | bool | False | _description_, by default False |
# | **Returns** | **_type_** |  | **_description_** |

# %%
#|output: asis
#| echo: false
show_doc(get_preprocess)
# Out:
# ---
#
# ### get_preprocess
#
# >      get_preprocess (cfg)
#
# Return preprocess function for particular model.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | cfg | cfg (omegaconf.DictConfig) | Hydra Configuration |
# | **Returns** | **_type_** | **_description_** |

# %%
#|output: asis
#| echo: false
show_doc(scalar)
# Out:
# ---
#
# ### scalar
#
# >      scalar (img:<module'PIL.Image'from'/opt/anaconda3/envs/rocks/lib/python3.
# >              10/site-packages/PIL/Image.py'>)
#
# Scale pixel between -1 and +1.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | img | PIL.Image | PIL Image |
# | **Returns** | **PIL.Image** | **imagew with pixel values scaled between -1 and 1** |

# %%
#|output: asis
#| echo: false
show_doc(get_value_counts)
# Out:
# ---
#
# ### get_value_counts
#
# >      get_value_counts (dataset_path:str)
#
# Get class counts of all classes in the dataset.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | dataset_path | str | directory with subclasses |
# | **Returns** | **None** |  |

# %%
#|output: asis
#| echo: false
show_doc(get_df)
# Out:
# ---
#
# ### get_df
#
# >      get_df (root:str='data/2_processed')
#
# Return df with classes, image paths and file names.
#
# |    | **Type** | **Default** | **Details** |
# | -- | -------- | ----------- | ----------- |
# | root | str | data/2_processed | directory to scan for image files, by default "data/2_processed" |
# | **Returns** | **DataFrame** |  | **with columns file_name, class and file_path** |

# %%
#|output: asis
#| echo: false
show_doc(get_dims)
# Out:
# ---
#
# ### get_dims
#
# >      get_dims (file:str)
#
# Return dimenstions for an RBG image.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | file | str | file path for image |
# | **Returns** | **Optional** | **returns a tuple of heights and width of image or None** |

# %%
#|output: asis
#| echo: false
show_doc(remove_corrupted_images)
# Out:
# ---
#
# ### timer_func.<locals>.wrap_func
#
# >      timer_func.<locals>.wrap_func (*args, **kwargs)

# %%
#|output: asis
#| echo: false
show_doc(remove_unsupported_images)
# Out:
# ---
#
# ### remove_unsupported_images
#
# >      remove_unsupported_images (root_folder:str)
#
# Remove unsupported images.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | root_folder | str | Root Folder. |

# %%
#|output: asis
#| echo: false
show_doc(find_filepaths)
# Out:
# ---
#
# ### find_filepaths
#
# >      find_filepaths (root_folder:str)
#
# Recursively finds all files.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | root_folder | str | _description_ |
# | **Returns** | **_type_** | **_description_** |

# %%
#|output: asis
#| echo: false
show_doc(timer_func)
# Out:
# ---
#
# ### timer_func
#
# >      timer_func (func)
#
# Show the execution time of the function object passed.
#
# |    | **Type** | **Details** |
# | -- | -------- | ----------- |
# | func | _type_ | _description_ |
